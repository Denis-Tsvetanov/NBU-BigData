# %% [markdown]
# # Контролно 2.
#
# Предаваме .ipynb в Moodle до 23:59 на 26.01.2022 г.

# %% [markdown]
# **Задача 1 (SVM)**. Имаме три точки, две от който са от клас "-1" и една е от клас "1" както следва:
# *   от клас "-1" са точките 0 и 2;
# *   от клас "1" е точката -1.
#
# ![image.png](data:image/png;base64,...)
#
# Пресметнете "на ръка":
# *   Лагранжиана в метода на опорните вектори (МОВ) с линейно ядро;
# *   стойностите на $\alpha$, при които този лагранжиан е най-малък и определете кои са опорните вектори;
# *   уравнението на разделителната линия в МОВ.
#
# Напишете код с sklearn, чрез който да потвърдите Вашите резултати.
#
# --
#
# В Moodle е качен файла "primer.pdf" с решението на подобна задача, която решавахме в час.

# %% [markdown]
# *решение "на ръка"*

# %%
# решение с sklearn

# %% [markdown]
# **Задача 2 (PCA)**. Прикачения dataset съдържа 1000 данни, всяка с 784 характеристики - колони `H1-H784`. Последната колона `y`  дава информация към кой от десетте класа принадлежи даден вектор.
#
# Задачи:
#
# 1. Използвайки sklearn намерете броя на главните оси, проекциите на началните вектори върху които дават обща дисперсия (explained variance) не по-малка от 95%.
# 2. Какъв процент от дисперсията дават проекциите върху първите две главни оси?
# 3. Всеки елемент от dataset-a нанесете като точка върху двумерна равнина, осите на която са първата и втората главна оси, използвайки подходяща библиотека за графики, напр. matplotlib. Данните от различните класове да са изобразени с различни цветове.

# %% [markdown]
# **Задача 3 (SVM)**. Използвайки 90% от данните от задача 1., обучете 9 + 8 + ... + 1 = 45 бинарни модела с машина на опорните вектори с линейни ядра, допускаща точки в разделящия коридор (,т.е. $C < \infty$) и 45 модела с логистична регресия. Всеки от моделите използва два различни класа от данните ( колоната `y`).
#
# Задачи:
# 1. Намерете 5-те двойки класове, които дават най-добри резултати в SVM и в LogReg като използвате останалите 10% от данните.
# 2. Кой от двата типа модели дава по-добри резултати?
# 3. Подобряват ли се резултатите ако мащабирате данните?
# 4. Чрез `GridSearchCV` на `sklearn` намерете най-добрите стойности на хиперпараметрите на SVM с нелинейни ядра. Как бихте оценили подобрението в точността на нелинейния модел спрямо тази на линейния модел?

# %% [markdown]
# ## Задачи с повишена трудност ("по желание")
#
# Предаваме задачите с повишена трудност в .ipynb в Moodle до 23:59 на 29.01.2022 г.

# %% [markdown]
# **Задача 4**. Да се намери уравнението на равнината, която преминава по средата на най-широкия възможен коридор между точките от двата класа :
#
# от клас "1" - (1,1), (1,-2)
# от клас "-1" - (-1, 1), (-1,-1)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Задача 5**. Изведете уравненията за L2 SVM, като последнователно занулите производните на лагранжиана $\mathcal{L}$ по $\omega, b, \xi$ и след това елиминирате тези параметри, изразявайки $\mathcal{L}$ само чрез $\alpha$ и $\beta$.
